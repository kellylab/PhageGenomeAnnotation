# %% [markdown]
# ####The purpose of this notebook is to work to annotate the Nahant Phage Genomes
#
# First up is gene calling.  Going to use two gene calling programs and then compare the output using ParsEval, a program designed to compare gene calls from two gff3 files.
#
# I'm going to start by working on only one genome.  Because of it's interesting characteristics that suggest it has host-like cas proteins, I'm going to work on phage 1.161.O.
#
# First look is to use Prodigal to call genes.  Prodigal is available on the server, so I'm going to create a submission script.

# %%
# !scp ./genomes/*fasta jbrown@eofe4.mit.edu:/nobackup1/jbrown/annotation/genomes/
# Out:
# 1.003.O.final.fasta                           100%   41KB  40.9KB/s   00:00
# 1.004.O.final.fasta                           100%   42KB  41.6KB/s   00:00
# 1.005.O.final.fasta                           100%   49KB  49.2KB/s   00:00
# 1.007.O.final.fasta                           100%   48KB  48.1KB/s   00:00
# 1.008.O.final.fasta                           100%   10KB  10.4KB/s   00:00
# 1.009.O.final.fasta                           100%   43KB  43.4KB/s   00:00
# 1.011.O.final.fasta                           100%   10KB  10.4KB/s   00:00
# 1.012.O.final.fasta                           100%   59KB  58.6KB/s   00:00
# 1.013.O.final.fasta                           100%   43KB  43.5KB/s   00:00
# 1.015.O.final.fasta                           100%   42KB  41.6KB/s   00:00
# 1.016.O.final.fasta                           100%   47KB  47.0KB/s   00:00
# 1.017.O.final.fasta                           100%   50KB  50.1KB/s   00:00
# ...
